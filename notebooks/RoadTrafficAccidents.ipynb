# %% [markdown]
# ## 1. Problem Statement

# %% [markdown]
# ### 1.1 Problem Statement

# %% [markdown]
# The Road Traffic Accidents Project is a Multiclass Classification Problem to identify whether the accident happened to be Slight Injury or Serious Injury

# %% [markdown]
# The data set has been prepared from manual records of road traffic accident of the year 2017-20. All the sensitive information have been excluded during data encoding and finally it has 32 features and 12316 instances of the accident. Then it is preprocessed and for identification of major causes of the accident by analyzing it using different machine learning classification algorithms algorithms. RTA Dataset.csv is the dataset before preprocessing and cleaned.csv is the preprocessed dataset.

# %% [markdown]
# ### 1.2 Load Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ### 1.3 Load Dataset

# %%
data = pd.read_csv('E:/RoadTrafficAccidents-App/data/raw/RTADataset.csv')
data.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle Defect_of_vehicle  \
# 0            Owner              Above 10yr         No defect
# 1            Owner                 5-10yrs         No defect
# 2            Owner                     NaN         No defect
# 3     Governmental                     NaN         No defect
# 4            Owner                 5-10yrs         No defect
#
#   Area_accident_occured   Lanes_or_Medians  \
# 0     Residential areas                NaN
# 1          Office areas  Undivided Two way
# 2    Recreational areas              other
# 3          Office areas              other
# 4      Industrial areas              other
#
#                                  Road_allignment Types_of_Junction  \
# 0                 Tangent road with flat terrain       No junction
# 1                 Tangent road with flat terrain       No junction
# 2                                            NaN       No junction
# 3  Tangent road with mild grade and flat terrain           Y Shape
# 4                 Tangent road with flat terrain           Y Shape
#
#   Road_surface_type Road_surface_conditions       Light_conditions  \
# 0     Asphalt roads                     Dry               Daylight
# 1     Asphalt roads                     Dry               Daylight
# 2     Asphalt roads                     Dry               Daylight
# 3       Earth roads                     Dry  Darkness - lights lit
# 4     Asphalt roads                     Dry  Darkness - lights lit
#
#   Weather_conditions                        Type_of_collision  \
# 0             Normal  Collision with roadside-parked vehicles
# 1             Normal           Vehicle with vehicle collision
# 2             Normal          Collision with roadside objects
# 3             Normal           Vehicle with vehicle collision
# 4             Normal           Vehicle with vehicle collision
#
#    Number_of_vehicles_involved  Number_of_casualties Vehicle_movement  \
# 0                            2                     2   Going straight
# 1                            2                     2   Going straight
# 2                            2                     2   Going straight
# 3                            2                     2   Going straight
# 4                            2                     2   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0               na              na                   na                na
# 1               na              na                   na                na
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4               na              na                   na                na
#
#   Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# 0               NaN                  NaN    Not a Pedestrian
# 1               NaN                  NaN    Not a Pedestrian
# 2            Driver                  NaN    Not a Pedestrian
# 3            Driver               Normal    Not a Pedestrian
# 4               NaN                  NaN    Not a Pedestrian
#
#             Cause_of_accident Accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury

# %%
data.columns = data.columns.str.lower()

# %%
data.head(20)
# Out:
#         time day_of_week age_band_of_driver sex_of_driver   educational_level  \
# 0   17:02:00      Monday              18-30          Male   Above high school
# 1   17:02:00      Monday              31-50          Male  Junior high school
# 2   17:02:00      Monday              18-30          Male  Junior high school
# 3    1:06:00      Sunday              18-30          Male  Junior high school
# 4    1:06:00      Sunday              18-30          Male  Junior high school
# 5   14:15:00      Friday              31-50          Male                 NaN
# 6   17:30:00   Wednesday              18-30          Male  Junior high school
# 7   17:20:00      Friday              18-30          Male  Junior high school
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 10  14:40:00    Saturday              18-30          Male   Above high school
# 11  14:40:00    Saturday              31-50          Male   Above high school
# 12  17:45:00    Thursday              18-30          Male  Junior high school
# 13  17:45:00    Thursday              31-50          Male  Junior high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
# 15  22:45:00      Monday              18-30        Female  Junior high school
# 16  22:45:00      Monday              18-30          Male  Junior high school
# 17  22:45:00      Monday              18-30          Male   Elementary school
# 18  22:45:00      Monday              18-30          Male  Junior high school
# 19   8:20:00     Tuesday              18-30          Male  Junior high school
#
#    vehicle_driver_relation driving_experience       type_of_vehicle  \
# 0                 Employee              1-2yr            Automobile
# 1                 Employee         Above 10yr   Public (> 45 seats)
# 2                 Employee              1-2yr       Lorry (41?100Q)
# 3                 Employee             5-10yr   Public (> 45 seats)
# 4                 Employee              2-5yr                   NaN
# 5                  Unknown                NaN                   NaN
# 6                 Employee              2-5yr            Automobile
# 7                 Employee              2-5yr            Automobile
# 8                 Employee         Above 10yr       Lorry (41?100Q)
# 9                 Employee              1-2yr            Automobile
# 10                   Owner              1-2yr  Public (13?45 seats)
# 11                Employee         No Licence            Automobile
# 12                Employee              1-2yr   Public (> 45 seats)
# 13                Employee             5-10yr       Lorry (41?100Q)
# 14                Employee         Above 10yr            Automobile
# 15                Employee         Above 10yr        Lorry (11?40Q)
# 16                   Owner             5-10yr  Public (13?45 seats)
# 17                Employee              2-5yr  Public (13?45 seats)
# 18                Employee              2-5yr                   NaN
# 19                Employee          Below 1yr            Long lorry
#
#    owner_of_vehicle service_year_of_vehicle defect_of_vehicle  \
# 0             Owner              Above 10yr         No defect
# 1             Owner                 5-10yrs         No defect
# 2             Owner                     NaN         No defect
# 3      Governmental                     NaN         No defect
# 4             Owner                 5-10yrs         No defect
# 5               NaN                     NaN               NaN
# 6             Owner                     NaN         No defect
# 7      Governmental              Above 10yr         No defect
# 8             Owner                   1-2yr         No defect
# 9             Owner                  2-5yrs         No defect
# 10            Owner                 Unknown         No defect
# 11            Owner                     NaN         No defect
# 12            Owner                  2-5yrs         No defect
# 13            Owner              Above 10yr         No defect
# 14            Owner                   1-2yr         No defect
# 15            Owner                     NaN         No defect
# 16            Owner                     NaN         No defect
# 17            Owner                     NaN         No defect
# 18            Owner              Above 10yr         No defect
# 19            Owner                 5-10yrs         No defect
#
#    area_accident_occured             lanes_or_medians  \
# 0      Residential areas                          NaN
# 1           Office areas            Undivided Two way
# 2     Recreational areas                        other
# 3           Office areas                        other
# 4       Industrial areas                        other
# 5                    NaN                          NaN
# 6      Residential areas            Undivided Two way
# 7      Residential areas                        other
# 8       Industrial areas                        other
# 9      Residential areas            Undivided Two way
# 10     Residential areas                        other
# 11          Office areas            Undivided Two way
# 12          Office areas  Double carriageway (median)
# 13          Office areas                        other
# 14          Office areas            Undivided Two way
# 15          Office areas                      One way
# 16          Office areas            Undivided Two way
# 17          Office areas                        other
# 18     Residential areas                        other
# 19     Residential areas                      One way
#
#                                   road_allignment types_of_junction  \
# 0                  Tangent road with flat terrain       No junction
# 1                  Tangent road with flat terrain       No junction
# 2                                             NaN       No junction
# 3   Tangent road with mild grade and flat terrain           Y Shape
# 4                  Tangent road with flat terrain           Y Shape
# 5                                             NaN           Y Shape
# 6                  Tangent road with flat terrain          Crossing
# 7                  Tangent road with flat terrain           Y Shape
# 8                  Tangent road with flat terrain           Y Shape
# 9                  Tangent road with flat terrain           Y Shape
# 10                 Tangent road with flat terrain       No junction
# 11                 Tangent road with flat terrain       No junction
# 12                                    Escarpments       No junction
# 13                 Tangent road with flat terrain       No junction
# 14                                    Escarpments       No junction
# 15                 Tangent road with flat terrain           Y Shape
# 16                 Tangent road with flat terrain           Y Shape
# 17                 Tangent road with flat terrain           Y Shape
# 18                 Tangent road with flat terrain           Y Shape
# 19                 Tangent road with flat terrain           Y Shape
#
#    road_surface_type road_surface_conditions       light_conditions  \
# 0      Asphalt roads                     Dry               Daylight
# 1      Asphalt roads                     Dry               Daylight
# 2      Asphalt roads                     Dry               Daylight
# 3        Earth roads                     Dry  Darkness - lights lit
# 4      Asphalt roads                     Dry  Darkness - lights lit
# 5                NaN                     Dry               Daylight
# 6                NaN                     Dry               Daylight
# 7      Asphalt roads                     Dry               Daylight
# 8        Earth roads                     Dry               Daylight
# 9      Asphalt roads                     Dry               Daylight
# 10     Asphalt roads                     Dry               Daylight
# 11       Earth roads                     Dry               Daylight
# 12     Asphalt roads                     Dry               Daylight
# 13     Asphalt roads                     Dry               Daylight
# 14     Asphalt roads                     Dry               Daylight
# 15     Asphalt roads             Wet or damp  Darkness - lights lit
# 16     Asphalt roads             Wet or damp  Darkness - lights lit
# 17     Asphalt roads             Wet or damp  Darkness - lights lit
# 18     Asphalt roads             Wet or damp  Darkness - lights lit
# 19     Asphalt roads                     Dry               Daylight
#
#    weather_conditions                        type_of_collision  \
# 0              Normal  Collision with roadside-parked vehicles
# 1              Normal           Vehicle with vehicle collision
# 2              Normal          Collision with roadside objects
# 3              Normal           Vehicle with vehicle collision
# 4              Normal           Vehicle with vehicle collision
# 5              Normal           Vehicle with vehicle collision
# 6              Normal           Vehicle with vehicle collision
# 7              Normal           Vehicle with vehicle collision
# 8              Normal  Collision with roadside-parked vehicles
# 9              Normal  Collision with roadside-parked vehicles
# 10             Normal                   Collision with animals
# 11             Normal                   Collision with animals
# 12             Normal                   Collision with animals
# 13             Normal                   Collision with animals
# 14             Normal                   Collision with animals
# 15            Raining                   Collision with animals
# 16            Raining                   Collision with animals
# 17            Raining                   Collision with animals
# 18            Raining                   Collision with animals
# 19             Normal                   Collision with animals
#
#     number_of_vehicles_involved  number_of_casualties vehicle_movement  \
# 0                             2                     2   Going straight
# 1                             2                     2   Going straight
# 2                             2                     2   Going straight
# 3                             2                     2   Going straight
# 4                             2                     2   Going straight
# 5                             1                     1           U-Turn
# 6                             1                     1  Moving Backward
# 7                             2                     1           U-Turn
# 8                             2                     1   Going straight
# 9                             2                     1           U-Turn
# 10                            2                     1         Turnover
# 11                            2                     1   Going straight
# 12                            2                     2   Going straight
# 13                            2                     2    Waiting to go
# 14                            2                     2   Going straight
# 15                            2                     3   Going straight
# 16                            2                     3   Going straight
# 17                            2                     3   Going straight
# 18                            2                     3  Moving Backward
# 19                            2                     1   Going straight
#
#      casualty_class sex_of_casualty age_band_of_casualty casualty_severity  \
# 0                na              na                   na                na
# 1                na              na                   na                na
# 2   Driver or rider            Male                31-50                 3
# 3        Pedestrian          Female                18-30                 3
# 4                na              na                   na                na
# 5   Driver or rider            Male                31-50                 3
# 6   Driver or rider          Female                18-30                 3
# 7                na              na                   na                na
# 8        Pedestrian            Male             Under 18                 3
# 9         Passenger            Male                18-30                 3
# 10               na              na                   na                na
# 11  Driver or rider            Male                18-30                 3
# 12               na              na                   na                na
# 13               na              na                   na                na
# 14  Driver or rider          Female                18-30                 3
# 15               na              na                   na                na
# 16               na              na                   na                na
# 17               na              na                   na                na
# 18               na              na                   na                na
# 19  Driver or rider            Male             Under 18                 3
#
#    work_of_casuality fitness_of_casuality              pedestrian_movement  \
# 0                NaN                  NaN                 Not a Pedestrian
# 1                NaN                  NaN                 Not a Pedestrian
# 2             Driver                  NaN                 Not a Pedestrian
# 3             Driver               Normal                 Not a Pedestrian
# 4                NaN                  NaN                 Not a Pedestrian
# 5             Driver               Normal                 Not a Pedestrian
# 6             Driver               Normal                 Not a Pedestrian
# 7                NaN               Normal                 Not a Pedestrian
# 8             Driver               Normal  Crossing from driver's nearside
# 9             Driver               Normal                 Not a Pedestrian
# 10               NaN               Normal                 Not a Pedestrian
# 11            Driver               Normal                 Not a Pedestrian
# 12            Driver               Normal                 Not a Pedestrian
# 13             Other               Normal                 Not a Pedestrian
# 14            Driver               Normal                 Not a Pedestrian
# 15               NaN                  NaN                 Not a Pedestrian
# 16            Driver               Normal                 Not a Pedestrian
# 17            Driver               Normal                 Not a Pedestrian
# 18        Unemployed               Normal                 Not a Pedestrian
# 19            Driver               Normal                 Not a Pedestrian
#
#              cause_of_accident accident_severity
# 0              Moving Backward     Slight Injury
# 1                   Overtaking     Slight Injury
# 2    Changing lane to the left    Serious Injury
# 3   Changing lane to the right     Slight Injury
# 4                   Overtaking     Slight Injury
# 5                  Overloading     Slight Injury
# 6                        Other     Slight Injury
# 7       No priority to vehicle     Slight Injury
# 8   Changing lane to the right     Slight Injury
# 9              Moving Backward    Serious Injury
# 10   Changing lane to the left    Serious Injury
# 11   No priority to pedestrian    Serious Injury
# 12               No distancing     Slight Injury
# 13      No priority to vehicle     Slight Injury
# 14               No distancing    Serious Injury
# 15               No distancing    Serious Injury
# 16             Moving Backward     Slight Injury
# 17  Changing lane to the right    Serious Injury
# 18   No priority to pedestrian     Slight Injury
# 19             Moving Backward    Serious Injury

# %%
data['Number_of_vehicles_involved'].value_counts()
# Out:
# 2    8340
# 1    1996
# 3    1568
# 4     363
# 6      42
# 7       7
# Name: Number_of_vehicles_involved, dtype: int64

# %%
data['Number_of_casualties'].value_counts()
# Out:
# 1    8397
# 2    2290
# 3     909
# 4     394
# 5     207
# 6      89
# 7      22
# 8       8
# Name: Number_of_casualties, dtype: int64

# %% [markdown]
# ## 2. Summarize Data

# %% [markdown]
# ### 2.1 Descriptive Statistics

# %% [markdown]
# ### 2.2 Data Visualizations

# %% [markdown]
# ## 3. Prepare Data

# %% [markdown]
# ### 3.1 Data Cleaning

# %% [markdown]
# ### 3.2 Feature Engineering

# %% [markdown]
# ### 3.3 Feature Selection

# %% [markdown]
# ## 4. Evaluate Algorithm

# %% [markdown]
# ### 4.1 Split Dataset
